# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cards = pd.read_csv('data/cards_cleaned.csv')
cards.head()
# Out:
#         name        id  wild  elixirCost  rarity  damage11  hitpoints11  \
# 0     Knight  26000000  both         3.0  common     202.0       1766.0
# 1    Archers  26000001   evo         3.0  common     214.0        304.0
# 2    Goblins  26000002  hero         2.0  common     360.0        202.0
# 3      Giant  26000003  hero         5.0    rare     254.0       4090.0
# 4  P.E.K.K.A  26000004   evo         7.0    epic     816.0       3760.0
#
#     type mobility    targets attack_type  groupCard  usage  Win Rate
# 0  troop   ground     ground      single      False   8.88     51.79
# 1  troop   ground       both      single       True   1.44     46.10
# 2  troop   ground     ground      single       True   3.60     54.32
# 3  troop   ground  buildings      single      False   2.32     59.10
# 4  troop   ground     ground      single      False   3.28     50.61

# %%
cards.info()
cards.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         120 non-null    object
#  1   id           120 non-null    int64
#  2   wild         120 non-null    object
#  3   elixirCost   120 non-null    float64
#  4   rarity       120 non-null    object
#  5   damage11     120 non-null    float64
#  6   hitpoints11  102 non-null    float64
#  7   type         120 non-null    object
#  8   mobility     120 non-null    object
#  9   targets      120 non-null    object
#  10  attack_type  120 non-null    object
#  11  groupCard    120 non-null    bool
#  12  usage        120 non-null    float64
#  13  Win Rate     120 non-null    float64
# dtypes: bool(1), float64(5), int64(1), object(7)
# memory usage: 12.4+ KB
#                  id  elixirCost     damage11  hitpoints11       usage  \
# ...

# %%
cards['type'].value_counts()
# Out:
# type
# troop       88
# spell       20
# building    12
# Name: count, dtype: int64

# %%
plt.scatter(cards['damage11'], cards['hitpoints11'])
plt.title('Card Damage vs. Health')
plt.xlabel('Damage')
plt.ylabel('Health')
#plt.savefig('./graphs/card_damage_vs_health.png')
plt.show()

# %%
plt.bar(cards['type'].unique(), cards['type'].value_counts())
plt.title('Card types')
plt.xlabel('Type')
plt.ylabel('Number of Cards')
#plt.savefig('./graphs/card_types.png')
plt.show()

# %%
plt.scatter(y = cards['usage'], x = cards['Win Rate'])
plt.title('Card usage vs win rate')
plt.ylabel('Usage (%)')
plt.xlabel('Win Rate (%)')
#plt.savefig('./graphs/card_usage_vs_win_rate.png')
plt.show()
